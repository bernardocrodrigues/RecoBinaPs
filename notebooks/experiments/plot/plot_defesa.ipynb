# %%
from evaluation.strategies import (
    PredictionCoverageStrategy,
    MAEStrategy,
    PrecisionAtKStrategy,
    RecallAtKStrategy,
    NDCGStrategy,
)


class TotalTimeStrategyMock:

    @staticmethod
    def get_name() -> str:
        return "total_time"

    @staticmethod
    def is_better_higher() -> bool:
        return False

# %%
# Load Raw Data

import json

result_root_folder = '../movielens_100k/'

# Adversary Models
with open(f"{result_root_folder}IB_BBCF_VANILLA_grid_raw.results", "r") as file_object:
    IB_BBCF_VANILLA = json.load(file_object)

with open(f"{result_root_folder}UB_BBCF_VANILLA_grid_raw.results", "r") as file_object:
    UB_BBCF_VANILLA = json.load(file_object)

with open(f"{result_root_folder}IBKNN_grid_raw.results", "r") as file_object:
    IBKNN = json.load(file_object)

with open(f"{result_root_folder}UBKNN_grid_raw.results", "r") as file_object:
    UBKNN = json.load(file_object)

with open(f"{result_root_folder}SVD_grid_raw.results", "r") as file_object:
    SVD = json.load(file_object)

with open(f"{result_root_folder}SVD++_grid_raw.results", "r") as file_object:
    SVDpp = json.load(file_object)


# My Models
with open(f"{result_root_folder}IB_BBCF_COSINE_grid_raw.results", "r") as file_object:
    IB_BBCF_COSINE = json.load(file_object)

with open(f"{result_root_folder}UB_BBCF_COSINE_grid_raw.results", "r") as file_object:
    UB_BBCF_COSINE = json.load(file_object)

with open(f"{result_root_folder}IB_BBCF_COSINE_DOUBLE_WEIGHT_grid_raw.results", "r") as file_object:
    IB_BBCF_COSINE_DOUBLE_WEIGHT = json.load(file_object)

with open(f"{result_root_folder}UB_BBCF_COSINE_DOUBLE_WEIGHT_grid_raw.results", "r") as file_object:
    UB_BBCF_COSINE_DOUBLE_WEIGHT = json.load(file_object)

with open(f"{result_root_folder}IB_BBCF_BINAPS_grid_raw.results", "r") as file_object:
    IB_BBCF_BINAPS = json.load(file_object)

with open(f"{result_root_folder}UB_BBCF_BINAPS_grid_raw.results", "r") as file_object:
    UB_BBCF_BINAPS = json.load(file_object)


def combine_solutions(labeled_solutions):
    combined_solutions = []
    for label, solutions in labeled_solutions:
        for solution in solutions:
            solution[0]["name"] = label
        combined_solutions += solutions
    return combined_solutions


def remove_impossible_solution(solutions):
    possible_solutions = []
    for solution in solutions:
        metrics = solution[1]

        impossible = any(None in values for key, values in metrics.items())
        if not impossible:
            possible_solutions.append(solution)
    return possible_solutions


IB_BBCF_BINAPS = remove_impossible_solution(IB_BBCF_BINAPS)
UB_BBCF_BINAPS = remove_impossible_solution(UB_BBCF_BINAPS)


all_solutions = [
    ("SVD", SVD),
    ("SVD++", SVDpp),
    ("CF IB", IBKNN),
    ("CF UB", UBKNN),
    ("IB BBCF", IB_BBCF_VANILLA),
    ("UB BBCF", UB_BBCF_VANILLA),
    ("UB BBCF + CS", UB_BBCF_COSINE),
    ("IB BBCF + CS", IB_BBCF_COSINE),
    ("IB BBCF + CS + CWF", IB_BBCF_COSINE_DOUBLE_WEIGHT),
    ("UB BBCF + CS + CWF", UB_BBCF_COSINE_DOUBLE_WEIGHT),
    ("IB BBCF + BMS", IB_BBCF_BINAPS),
    ("UB BBCF + BMS", UB_BBCF_BINAPS),
]
combined_solutions = combine_solutions(all_solutions)
labels = [label for label, _ in all_solutions]

for param, metrics in combined_solutions:
    total_time = [
        fit_time + test_time
        for fit_time, test_time in zip(metrics["fit_time"], metrics["test_time"])
    ]
    metrics["total_time"] = total_time

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import numba as nb


def dominates(a, b, objectives):

    partial_result = []
    for objective in objectives:
        direction = 1 if objective.is_better_higher() else -1

        a_mean = np.mean(a[objective.get_name()])
        b_mean = np.mean(b[objective.get_name()])

        if direction * a_mean >= direction * b_mean:
            partial_result.append(True)
        else:
            partial_result.append(False)

    return all(partial_result)


def get_all_strongly_dominated_solutions(solution, solutions, objectives):
    return [id for id, s in enumerate(solutions) if dominates(solution[1], s[1], objectives)]


def remove_indices(lst, indices):
    list_with_indices_removed = [el for i, el in enumerate(lst) if i not in indices]
    indices_removed = [el for i, el in enumerate(lst) if i in indices]
    return list_with_indices_removed, indices_removed


def get_pareto_frontier(solutions, objectives):

    pareto_frontier = solutions
    dominated_solutions = []

    searching = True
    while searching:
        for solution_id, solution in enumerate(pareto_frontier):

            pareto_frontier_without_solution = [
                s for i, s in enumerate(pareto_frontier) if i != solution_id
            ]

            strongly_dominated_solutions = get_all_strongly_dominated_solutions(
                solution, pareto_frontier_without_solution, objectives
            )
            if strongly_dominated_solutions:
                pareto_frontier_without_solution, removed = remove_indices(
                    pareto_frontier_without_solution, strongly_dominated_solutions
                )
                pareto_frontier_without_solution.append(solution)
                pareto_frontier = pareto_frontier_without_solution
                dominated_solutions += removed
                break
        else:
            searching = False

    return pareto_frontier, dominated_solutions


def filter_solutions_that_guarantee_minimum(solutions, metric, value):
    filtered = []
    for parameters, metrics in solutions:
        if np.mean(metrics[metric]) >= value:
            filtered.append((parameters, metrics))
    return filtered


def filter_solutions(solutions, fixed_parameters):
    filtered = []
    for parameters, metrics in solutions:

        for key, value in fixed_parameters.items():

            if type(value) == dict:

                to_break = False

                for sub_key, sub_value in value.items():
                    if parameters[key][sub_key] != sub_value:
                        to_break = True
                        break

                if to_break:
                    break

            else:
                if parameters[key] != value:
                    break
        else:
            filtered.append((parameters, metrics))

    return filtered


def sort_pareto_frontier(pareto_frontier, labels):
    sorted_pareto_frontier = {}
    for label in labels:
        sorted_pareto_frontier[label] = []

    for solution in pareto_frontier:
        sorted_pareto_frontier[solution[0]["name"]].append(solution)

    return sorted_pareto_frontier


def add_frontier(axis, pareto_frontier, color, marker, name, objectives, makers=False):

    objective_1_name = objectives[0].get_name()

    objective_2_name = objectives[1].get_name()

    objective_1 = [np.mean(execution[1][objective_1_name]) for execution in pareto_frontier]
    objective_2 = [np.mean(execution[1][objective_2_name]) for execution in pareto_frontier]

    sorted_ids = np.argsort(objective_1)

    objective_1 = [objective_1[i] for i in sorted_ids]
    objective_2 = [objective_2[i] for i in sorted_ids]

    if makers:
        axis.plot(
            objective_1,
            objective_2,
            label=name,
            color=color,
            linewidth=3,
            marker=marker,
            markersize=10,
        )
    else:
        axis.plot(objective_1, objective_2, label=name, color=color, linewidth=3)

    return np.min(objective_1), np.max(objective_1), np.min(objective_2), np.max(objective_2)


def add_scatter(axis, solutions, color, marker, label, objectives):

    objective_1_name = objectives[0].get_name()

    objective_2_name = objectives[1].get_name()

    objective_1 = [np.mean(execution[1][objective_1_name]) for execution in solutions]
    objective_2 = [np.mean(execution[1][objective_2_name]) for execution in solutions]

    axis.scatter(
        objective_1,
        objective_2,
        label=label,
        marker=marker,
        color=color,
        s=80,
        zorder=2,
    )


color_map = {
    "SVD": "deepskyblue",
    "SVD++": "magenta",
    "CF IB": "lime",
    "CF UB": "orangered",
    "IB BBCF": "blueviolet",
    "UB BBCF": "hotpink",
    "UB BBCF + CS": "gold",
    "IB BBCF + CS": "brown",
    "IB BBCF + CS + CWF": "gray",
    "UB BBCF + CS + CWF": "aquamarine",
    "IB BBCF + BMS": "navy",
    "UB BBCF + BMS": "teal",
}

marker_map = {
    "SVD": "o",
    "SVD++": "s",
    "CF IB": "v",
    "CF UB": "^",
    "IB BBCF": "<",
    "UB BBCF": ">",
    "UB BBCF + CS": "8",
    "IB BBCF + CS": "p",
    "IB BBCF + CS + CWF": "P",
    "UB BBCF + CS + CWF": "*",
    "IB BBCF + BMS": "h",
    "UB BBCF + BMS": "H",
}


pretty_names = {
    "mae": "MAE",
    "precision_at_k": "Precision@20",
    "recall_at_k": "Recall@20",
    "nDCG_at_k": "nDCG@20",
    "prediction_coverage": "Prediction Coverage",
    "total_time": "Total Time (s)",
}

# %%
from matplotlib.ticker import FuncFormatter
plt.rcParams["font.size"] = 14  # Set the default font size
figure_size = (12, 5)

# %%
fig, axis = plt.subplots(1, 2, figsize=figure_size)


objectives_list = [
    [TotalTimeStrategyMock, MAEStrategy],
    [TotalTimeStrategyMock, PrecisionAtKStrategy],
]


for axis_id, objectives in enumerate(objectives_list):
    solutions_with_20_coverage = filter_solutions_that_guarantee_minimum(
        combined_solutions,
        "prediction_coverage",
        0.2,
    )
    pareto_with_20_coverage, _ = get_pareto_frontier(solutions_with_20_coverage, objectives)

    solutions_with_40_coverage = filter_solutions_that_guarantee_minimum(
        combined_solutions,
        "prediction_coverage",
        0.4,
    )
    pareto_with_40_coverage, _ = get_pareto_frontier(solutions_with_40_coverage, objectives)

    solutions_with_60_coverage = filter_solutions_that_guarantee_minimum(
        combined_solutions,
        "prediction_coverage",
        0.6,
    )
    pareto_with_60_coverage, _ = get_pareto_frontier(solutions_with_60_coverage, objectives)

    solutions_with_80_coverage = filter_solutions_that_guarantee_minimum(
        combined_solutions,
        "prediction_coverage",
        0.8,
    )
    pareto_with_80_coverage, _ = get_pareto_frontier(solutions_with_80_coverage, objectives)

    x_mins = []
    x_maxs = []
    y_mins = []
    y_maxs = []

    x_min, x_max, y_min, y_max = add_frontier(axis[axis_id], pareto_with_20_coverage, "blue", "v", "20%+ Coverage", objectives)
    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)
    y_maxs.append(y_max)

    x_min, x_max, y_min, y_max = add_frontier(axis[axis_id], pareto_with_40_coverage, "red", "v", "40%+ Coverage", objectives)
    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)
    y_maxs.append(y_max)

    x_min, x_max, y_min, y_max = add_frontier(axis[axis_id], pareto_with_60_coverage, "green", "v", "60%+ Coverage", objectives)
    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)
    y_maxs.append(y_max)

    x_min, x_max, y_min, y_max = add_frontier(axis[axis_id], pareto_with_80_coverage, "black", "v", "80%+ Coverage", objectives)
    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)
    y_maxs.append(y_max)

    sorted_pareto = sort_pareto_frontier(
        pareto_with_20_coverage
        + pareto_with_40_coverage
        + pareto_with_60_coverage
        + pareto_with_80_coverage,
        labels,
    )

    for label, solutions in sorted_pareto.items():
        if len(solutions) > 0:
            add_scatter(
                axis[axis_id],
                solutions,
                color_map[label],
                marker_map[label],
                label,
                objectives,
            )

    if objectives[0].is_better_higher():
        axis[axis_id].invert_xaxis()

    if objectives[1].is_better_higher():
        axis[axis_id].invert_yaxis()

    axis[axis_id].set_xlabel(pretty_names[objectives[0].get_name()])
    axis[axis_id].set_ylabel(pretty_names[objectives[1].get_name()])

    axis[axis_id].legend(loc="upper right", ncol=2, fontsize=11)
    axis[axis_id].xaxis.set_minor_locator(
        ticker.AutoMinorLocator(2)
    )  # Draw 2 minor grid lines per major grid line on the x-axis
    axis[axis_id].yaxis.set_minor_locator(ticker.AutoMinorLocator(2))
    axis[axis_id].grid(True, which="major", color="lightgray")
    axis[axis_id].grid(True, which="minor", color="whitesmoke")

    axis[axis_id].set_title("(a)" if axis_id == 0 else "(b)", loc="center")

    steps = 6
    min_value = min(x_mins)
    max_value = max(x_maxs)

    step = (max_value - min_value) / steps
    ticks = np.arange(min_value, max_value + step, step)
    axis[axis_id].set_xticks(ticks)

    axis[axis_id].xaxis.set_major_formatter(
        FuncFormatter(lambda x, _: f"{x:.2f}" if x < 2 else f"{x:.0f}")
    )

    steps = 7
    min_value = min(y_mins)
    max_value = max(y_maxs)

    step = (max_value - min_value) / steps
    ticks = np.arange(min_value, max_value + step, step)
    axis[axis_id].set_yticks(ticks)

    axis[axis_id].yaxis.set_major_formatter(
        FuncFormatter(lambda x, _: f"{x:.2f}" if x < 2 else f"{x:.0f}")
    )


plt.tight_layout()
# plt.show()
# plt.savefig("image.png", dpi=100, bbox_inches='tight', pad_inches = 0.01)
plt.savefig("image.png", dpi=150)

# %%
fig, axis = plt.subplots(1, 2, figsize=figure_size)


objectives_list = [
    [TotalTimeStrategyMock, RecallAtKStrategy],
    [TotalTimeStrategyMock, NDCGStrategy],
]


for axis_id, objectives in enumerate(objectives_list):
    solutions_with_20_coverage = filter_solutions_that_guarantee_minimum(
        combined_solutions,
        "prediction_coverage",
        0.2,
    )
    pareto_with_20_coverage, _ = get_pareto_frontier(solutions_with_20_coverage, objectives)

    solutions_with_40_coverage = filter_solutions_that_guarantee_minimum(
        combined_solutions,
        "prediction_coverage",
        0.4,
    )
    pareto_with_40_coverage, _ = get_pareto_frontier(solutions_with_40_coverage, objectives)

    solutions_with_60_coverage = filter_solutions_that_guarantee_minimum(
        combined_solutions,
        "prediction_coverage",
        0.6,
    )
    pareto_with_60_coverage, _ = get_pareto_frontier(solutions_with_60_coverage, objectives)

    solutions_with_80_coverage = filter_solutions_that_guarantee_minimum(
        combined_solutions,
        "prediction_coverage",
        0.8,
    )
    pareto_with_80_coverage, _ = get_pareto_frontier(solutions_with_80_coverage, objectives)

    x_mins = []
    x_maxs = []
    y_mins = []
    y_maxs = []

    x_min, x_max, y_min, y_max = add_frontier(axis[axis_id], pareto_with_20_coverage, "blue", "v", "20%+ Coverage", objectives)
    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)
    y_maxs.append(y_max)

    x_min, x_max, y_min, y_max = add_frontier(axis[axis_id], pareto_with_40_coverage, "red", "v", "40%+ Coverage", objectives)
    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)
    y_maxs.append(y_max)

    x_min, x_max, y_min, y_max = add_frontier(axis[axis_id], pareto_with_60_coverage, "green", "v", "60%+ Coverage", objectives)
    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)
    y_maxs.append(y_max)

    x_min, x_max, y_min, y_max = add_frontier(axis[axis_id], pareto_with_80_coverage, "black", "v", "80%+ Coverage", objectives)
    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)
    y_maxs.append(y_max)

    sorted_pareto = sort_pareto_frontier(
        pareto_with_20_coverage
        + pareto_with_40_coverage
        + pareto_with_60_coverage
        + pareto_with_80_coverage,
        labels,
    )

    for label, solutions in sorted_pareto.items():
        if len(solutions) > 0:
            add_scatter(
                axis[axis_id],
                solutions,
                color_map[label],
                marker_map[label],
                label,
                objectives,
            )

    if objectives[0].is_better_higher():
        axis[axis_id].invert_xaxis()

    if objectives[1].is_better_higher():
        axis[axis_id].invert_yaxis()

    axis[axis_id].set_xlabel(pretty_names[objectives[0].get_name()])
    axis[axis_id].set_ylabel(pretty_names[objectives[1].get_name()])

    axis[axis_id].legend(loc="upper right", ncol=2, fontsize=11)
    axis[axis_id].xaxis.set_minor_locator(ticker.AutoMinorLocator(2))
    axis[axis_id].yaxis.set_minor_locator(ticker.AutoMinorLocator(2))
    axis[axis_id].grid(True, which="major", color="lightgray")
    axis[axis_id].grid(True, which="minor", color="whitesmoke")

    axis[axis_id].set_title("(a)" if axis_id == 0 else "(b)", loc="center")

    steps = 6
    min_value = min(x_mins)
    max_value = max(x_maxs)

    step = (max_value - min_value) / steps
    ticks = np.arange(min_value, max_value + step, step)
    axis[axis_id].set_xticks(ticks)

    axis[axis_id].xaxis.set_major_formatter(
        FuncFormatter(lambda x, _: f"{x:.2f}" if x < 2 else f"{x:.0f}")
    )

    steps = 7
    min_value = min(y_mins)
    max_value = max(y_maxs)

    step = (max_value - min_value) / steps
    ticks = np.arange(min_value, max_value + step, step)
    axis[axis_id].set_yticks(ticks)

    axis[axis_id].yaxis.set_major_formatter(
        FuncFormatter(lambda x, _: f"{x:.2f}" if x < 2 else f"{x:.0f}")
    )

axis[1].legend(loc="lower right", ncol=1, fontsize=10)


plt.tight_layout()
# plt.show()
# plt.savefig("image.png", dpi=100, bbox_inches='tight', pad_inches = 0.01)
plt.savefig("image.png", dpi=150)

# %%
fig, axis = plt.subplots(1, 2, figsize=figure_size)

objectives = [PredictionCoverageStrategy, MAEStrategy]

algorithm_list = [
    ("IB BBCF", IB_BBCF_VANILLA),
    ("IB BBCF + CS + CWF", IB_BBCF_COSINE_DOUBLE_WEIGHT),
]


fixed_parameters = [
    {"knn_k": 20},
    {"knn_k": 50},
    {"knn_k": 100},
    {"knn_k": 200},
]

labels = ["k=20", "k=50", "k=100", "k=200"]
colors = ["blue", "red", "green", "black"]
markers = ["v", "s", "o", "D"]

for alg_id, (name, algorithm) in enumerate(algorithm_list):

    x_mins = []
    x_maxs = []
    y_mins = []
    y_maxs = []

    filtered = []
    for fixed_parameter in fixed_parameters:
        filtered.append(filter_solutions(algorithm, fixed_parameter))

    paretos = []
    for filtered in filtered:
        pareto_frontier, _ = get_pareto_frontier(filtered, objectives)
        paretos.append(pareto_frontier)

    for pareto, label, color, marker in zip(paretos, labels, colors, markers):

        x_min, x_max, y_min, y_max = add_frontier(
            axis[alg_id], pareto, color, marker, label, objectives, makers=True
        )
        x_mins.append(x_min)
        x_maxs.append(x_max)
        y_mins.append(y_min)
        y_maxs.append(y_max)

        if objectives[0].is_better_higher():
            axis[alg_id].invert_xaxis()

        if objectives[1].is_better_higher():
            axis[alg_id].invert_yaxis()

    axis[alg_id].set_xlabel(pretty_names[objectives[0].get_name()])
    axis[alg_id].set_ylabel(pretty_names[objectives[1].get_name()])

    axis[alg_id].legend(loc="upper right", ncol=2, fontsize=11)
    axis[alg_id].grid(True, which="major", color="lightgray")
    axis[alg_id].grid(True, which="minor", color="whitesmoke")

    
    steps = 6
    min_value = min(x_mins)
    max_value = max(x_maxs)
    middle_ticks = np.arange(round(min_value, 1) + 0.1, max_value - 0.1 , 0.1)
    ticks = [min_value] + list(middle_ticks) + [max_value]
    axis[alg_id].set_xticks(ticks)
    axis[alg_id].xaxis.set_major_formatter(
        FuncFormatter(lambda x, _: f"{x:.3f}" if x not in np.arange(0.1, 1, 0.1) else f"{x:.1f}")
    )

    steps = 7
    min_value = min(y_mins)
    max_value = max(y_maxs)
    # middle_ticks = np.arange(round(min_value, 1) + 0.1, max_value - 0.1 , 0.1)
    # ticks = [min_value] + list(middle_ticks) + [max_value]
    step = (max_value - min_value) / steps
    ticks = np.arange(min_value, max_value + step, step)
    axis[alg_id].set_yticks(ticks)
    axis[alg_id].yaxis.set_major_formatter(
        FuncFormatter(lambda x, _: f"{x:.2f}")
    )

    if objectives[0].is_better_higher():
        axis[alg_id].invert_xaxis()

    if objectives[1].is_better_higher():
        axis[alg_id].invert_yaxis()

    axis[alg_id].set_title(f"(a) {name}" if alg_id == 0 else f"(b) {name}", loc="center")

    # axis[alg_id].set_title(name)

plt.tight_layout()
# plt.show()
plt.savefig("image.png", dpi=150)

# %%
fig, axis = plt.subplots(1, 2, figsize=figure_size)

objectives_list = [
    [PredictionCoverageStrategy, MAEStrategy],
    [PredictionCoverageStrategy, RecallAtKStrategy],
]

fixed_parameters = [
    {"number_of_top_k_biclusters": 10},
    {"number_of_top_k_biclusters": 50},
    {"number_of_top_k_biclusters": 100},
    {"number_of_top_k_biclusters": 200},
]

labels = ["k_tp=20", "k_tp=50", "k_tp=100", "k_tp=200"]
colors = ["blue", "red", "green", "black"]
markers = ["v", "s", "o", "D"]

for alg_id, objectives in enumerate(objectives_list):

    x_mins = []
    x_maxs = []
    y_mins = []
    y_maxs = []

    filtered = []
    for fixed_parameter in fixed_parameters:
        filtered.append(filter_solutions(IB_BBCF_VANILLA, fixed_parameter))

    paretos = []
    for filtered in filtered:
        pareto_frontier, _ = get_pareto_frontier(filtered, objectives)
        paretos.append(pareto_frontier)

    for pareto, label, color, marker in zip(paretos, labels, colors, markers):

        x_min, x_max, y_min, y_max = add_frontier(axis[alg_id], pareto, color, marker, label, objectives, True)

        x_mins.append(x_min)
        x_maxs.append(x_max)
        y_mins.append(y_min)    
        y_maxs.append(y_max)
        
        if objectives[0].is_better_higher():
            axis[alg_id].invert_xaxis()

        if objectives[1].is_better_higher():
            axis[alg_id].invert_yaxis()

    axis[alg_id].set_xlabel(pretty_names[objectives[0].get_name()])
    axis[alg_id].set_ylabel(pretty_names[objectives[1].get_name()])

    axis[alg_id].legend(loc="upper right", ncol=2, fontsize=11)

    axis[alg_id].yaxis.set_minor_locator(ticker.AutoMinorLocator(2))
    axis[alg_id].grid(True, which="major", color="lightgray")
    axis[alg_id].grid(True, which="minor", color="whitesmoke")

    if objectives[0].is_better_higher():
        axis[alg_id].invert_xaxis()

    if objectives[1].is_better_higher():
        axis[alg_id].invert_yaxis()

    axis[alg_id].set_title("(a)" if alg_id == 0 else "(b)", loc="center")

    steps = 2
    min_value = min(x_mins)
    max_value = max(x_maxs)
    middle_ticks = np.arange(round(min_value, 1) + 0.1, max_value - 0.1 , 0.1)
    ticks = [min_value] + list(middle_ticks) + [max_value]
    axis[alg_id].set_xticks(ticks)
    axis[alg_id].xaxis.set_major_formatter(
        FuncFormatter(lambda x, _: f"{x:.3f}" if x not in np.arange(0.1, 1, 0.1) else f"{x:.1f}")
    )

    steps = 7
    min_value = min(y_mins)
    max_value = max(y_maxs)
    step = (max_value - min_value) / steps
    ticks = np.arange(min_value, max_value + step, step)
    axis[alg_id].set_yticks(ticks)
    axis[alg_id].yaxis.set_major_formatter(
        FuncFormatter(lambda x, _: f"{x:.2f}")
    )

fig.suptitle("IB BBCF")
plt.tight_layout()
# plt.show()
plt.savefig("image.png", dpi=150)

# %%
fig, axis = plt.subplots(1, 2, figsize=figure_size)

objectives = [PredictionCoverageStrategy, MAEStrategy]
algorithm_list = [
    ("SVD", SVD),
    ("SVD++", SVDpp),
    ("CF IB", IBKNN),
    ("CF UB", UBKNN),
    ("IB BBCF", IB_BBCF_VANILLA),
    ("UB BBCF", UB_BBCF_VANILLA),
    ("UB BBCF + CS", UB_BBCF_COSINE),
    ("IB BBCF + CS", IB_BBCF_COSINE),
    ("IB BBCF + CS + CWF", IB_BBCF_COSINE_DOUBLE_WEIGHT),
    ("UB BBCF + CS + CWF", UB_BBCF_COSINE_DOUBLE_WEIGHT),
]

x_mins = []
x_maxs = []
y_mins = []
y_maxs = []

for name, algorithm in algorithm_list:

    pareto_frontier, _ = get_pareto_frontier(algorithm, objectives)
    x_min, x_max, y_min, y_max = add_frontier(axis[0], pareto_frontier, color_map[name], marker_map[name], name, objectives, True)
    add_scatter(axis[0], pareto_frontier, color_map[name], marker_map[name], "", objectives)

    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)    
    y_maxs.append(y_max)


axis[0].set_xlabel(pretty_names[objectives[0].get_name()])
axis[0].set_ylabel(pretty_names[objectives[1].get_name()])

axis[0].legend(loc="lower left", ncol=2, fontsize=11)
axis[0].grid(True, which="major", color="lightgray")
axis[0].grid(True, which="minor", color="whitesmoke")

if objectives[0].is_better_higher():
    axis[0].invert_xaxis()

if objectives[1].is_better_higher():
    axis[0].invert_yaxis()
axis[0].set_title("(a)", loc="center")


steps = 2
min_value = min(x_mins)
max_value = max(x_maxs)
middle_ticks = np.arange(0.1, 1, 0.1)
ticks = [min_value] + list(middle_ticks) + [max_value]
axis[0].set_xticklabels(axis[0].get_xticks(), rotation=-20)
axis[0].set_xticks(ticks)
axis[0].xaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.3f}" if x not in np.arange(0.1, 1.1, 0.1) else f"{x:.1f}")
)

steps = 7
min_value = min(y_mins)
max_value = max(y_maxs)
step = (max_value - min_value) / steps
ticks = np.arange(min_value, max_value + step, step)
axis[0].set_yticks(ticks)
axis[0].yaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.2f}")
)


objectives = [PredictionCoverageStrategy, RecallAtKStrategy]

x_mins = []
x_maxs = []
y_mins = []
y_maxs = []


for name, algorithm in algorithm_list:

    pareto_frontier, _ = get_pareto_frontier(algorithm, objectives)
    x_min, x_max, y_min, y_max = add_frontier(axis[1], pareto_frontier, color_map[name], marker_map[name], name, objectives, True)
    add_scatter(axis[1], pareto_frontier, color_map[name], marker_map[name], "", objectives)

    x_mins.append(x_min)
    x_maxs.append(x_max)
    y_mins.append(y_min)    
    y_maxs.append(y_max)


axis[1].set_xlabel(pretty_names[objectives[0].get_name()])
axis[1].set_ylabel(pretty_names[objectives[1].get_name()])

axis[1].legend(loc="lower left", ncol=1, fontsize=10)

axis[1].grid(True, which="major", color="lightgray")
axis[1].grid(True, which="minor", color="whitesmoke")

if objectives[0].is_better_higher():
    axis[1].invert_xaxis()

if objectives[1].is_better_higher():
    axis[1].invert_yaxis()
axis[1].set_title("(b)", loc="center")


steps = 2
min_value = min(x_mins)
max_value = max(x_maxs)
middle_ticks = np.arange(0.2, 1.1, 0.1)
ticks = [min_value] + list(middle_ticks)
axis[1].set_xticklabels(axis[0].get_xticks(), rotation=-60)
axis[1].set_xticks(ticks)
axis[1].xaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.2f}" if x not in np.arange(0.2, 1.1, 0.1) else f"{x:.1f}")
)

steps = 7
min_value = min(y_mins)
max_value = max(y_maxs)
step = (max_value - min_value) / steps
ticks = np.arange(min_value, max_value + step, step)
axis[1].set_yticks(ticks)
axis[1].yaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.2f}")
)


plt.tight_layout()
# plt.show()
plt.savefig("image.png", dpi=150)
# Out:
# /tmp/ipykernel_1/1660507602.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis[0].set_xticklabels(axis[0].get_xticks(), rotation=-20)
# /tmp/ipykernel_1/1660507602.py:112: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis[1].set_xticklabels(axis[0].get_xticks(), rotation=-60)

# %%
fig, axis = plt.subplots(1, 2, figsize=figure_size)

objectives = [PredictionCoverageStrategy, MAEStrategy]

algorithm_list = [
    ("SVD", SVD),
    ("SVD++", SVDpp),
    ("CF IB", IBKNN),
    ("CF UB", UBKNN),
    ("IB BBCF", IB_BBCF_VANILLA),
    ("UB BBCF", UB_BBCF_VANILLA),
    ("UB BBCF + CS", UB_BBCF_COSINE),
    ("IB BBCF + CS", IB_BBCF_COSINE),
    ("IB BBCF + CS + CWF", IB_BBCF_COSINE_DOUBLE_WEIGHT),
    ("UB BBCF + CS + CWF", UB_BBCF_COSINE_DOUBLE_WEIGHT),
    ("IB BBCF + BMS", IB_BBCF_BINAPS),
    ("UB BBCF + BMS", UB_BBCF_BINAPS),
]

labels = [label for label, _ in algorithm_list]

combined_pareto_frontier, _ = get_pareto_frontier(combined_solutions, objectives)
sorted_pareto = sort_pareto_frontier(combined_pareto_frontier, labels)
x_min, x_max, y_min, y_max = add_frontier(axis[0], combined_pareto_frontier, "black", 'v', "Global P. Frontier", objectives)

for label, pareto in sorted_pareto.items():
    if len(pareto) > 0:
        add_scatter(axis[0], pareto, color_map[label], marker_map[label],
                    label, objectives)

if objectives[0].is_better_higher():
    axis[0].invert_xaxis()

if objectives[1].is_better_higher():
    axis[0].invert_yaxis()


axis[0].set_xlabel(pretty_names[objectives[0].get_name()])
axis[0].set_ylabel(pretty_names[objectives[1].get_name()])

axis[0].legend(loc="lower left", ncol=1, fontsize=11)


axis[0].grid(True, which="major", color="lightgray")
axis[0].grid(True, which="minor", color="whitesmoke")
axis[0].set_title("(a)", loc="center")

middle_ticks = np.arange(0.1, 1.1, 0.1)
ticks = [x_min] + list(middle_ticks)
axis[0].set_xticklabels(axis[0].get_xticks(), rotation=-60)
axis[0].set_xticks(ticks)
axis[0].xaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.3f}" if x not in np.arange(0.1, 1.1, 0.1) else f"{x:.1f}")
)

steps = 7
step = (y_max - y_min) / steps
ticks = np.arange(y_min, y_max + step, step)
axis[0].set_yticks(ticks)
axis[0].yaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.2f}")
)


objectives = [PredictionCoverageStrategy, PrecisionAtKStrategy]


combined_pareto_frontier, _ = get_pareto_frontier(combined_solutions, objectives)
sorted_pareto = sort_pareto_frontier(combined_pareto_frontier, labels)

x_min, x_max, y_min, y_max = add_frontier(axis[1], combined_pareto_frontier, "black",'v', "Global P. Frontier", objectives)

for label, pareto in sorted_pareto.items():
    if len(pareto) > 0:
        add_scatter(axis[1], pareto, color_map[label], marker_map[label], label, objectives)

if objectives[0].is_better_higher():
    axis[1].invert_xaxis()

if objectives[1].is_better_higher():
    axis[1].invert_yaxis()

axis[1].set_xlabel(pretty_names[objectives[0].get_name()])
axis[1].set_ylabel(pretty_names[objectives[1].get_name()])

axis[1].legend(loc="upper right", ncol=1, fontsize=11)

axis[1].grid(True, which="major", color="lightgray")
axis[1].grid(True, which="minor", color="whitesmoke")
axis[1].set_title("(b)", loc="center")


middle_ticks = np.arange(0.2, 1.1, 0.1)
ticks = [x_min] + list(middle_ticks)
axis[1].set_xticklabels(axis[0].get_xticks(), rotation=-60)
axis[1].set_xticks(ticks)
axis[1].xaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.3f}" if x not in np.arange(0.2, 1.1, 0.1) else f"{x:.1f}")
)

steps = 7
step = (y_max - y_min) / steps
ticks = np.arange(y_min, y_max + step, step)
axis[1].set_yticks(ticks)
axis[1].yaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.2f}")
)



plt.tight_layout()
# plt.show()
plt.savefig("image.png", dpi=150)
# Out:
# /tmp/ipykernel_1/4172066785.py:50: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis[0].set_xticklabels(axis[0].get_xticks(), rotation=-60)
# /tmp/ipykernel_1/4172066785.py:95: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis[1].set_xticklabels(axis[0].get_xticks(), rotation=-60)

# %%
fig, axis = plt.subplots(1, 2, figsize=figure_size)


objectives = [PredictionCoverageStrategy, RecallAtKStrategy]


combined_pareto_frontier, _ = get_pareto_frontier(combined_solutions, objectives)
sorted_pareto = sort_pareto_frontier(combined_pareto_frontier, labels)
x_min, x_max, y_min, y_max = add_frontier(axis[0], combined_pareto_frontier, "black", 'v', "Global P. Frontier", objectives)

for label, pareto in sorted_pareto.items():
    if len(pareto) > 0:
        add_scatter(axis[0], pareto, color_map[label], marker_map[label], label, objectives)

if objectives[0].is_better_higher():
    axis[0].invert_xaxis()

if objectives[1].is_better_higher():
    axis[0].invert_yaxis()


axis[0].set_xlabel(pretty_names[objectives[0].get_name()])
axis[0].set_ylabel(pretty_names[objectives[1].get_name()])

axis[0].legend(loc="lower left", ncol=1, fontsize=11)
axis[0].grid(True, which="major", color="lightgray")
axis[0].grid(True, which="minor", color="whitesmoke")
axis[0].set_title("(a)", loc="center")

middle_ticks = np.arange(0.2, 1.1, 0.1)
ticks = [x_min] + list(middle_ticks)
axis[0].set_xticklabels(axis[0].get_xticks(), rotation=-60)
axis[0].set_xticks(ticks)
axis[0].xaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.3f}" if x not in np.arange(0.2, 1.1, 0.1) else f"{x:.1f}")
)

steps = 7
step = (y_max - y_min) / steps
ticks = np.arange(y_min, y_max + step, step)
axis[0].set_yticks(ticks)
axis[0].yaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.2f}")
)


objectives = [PredictionCoverageStrategy, NDCGStrategy]


combined_pareto_frontier, _ = get_pareto_frontier(combined_solutions, objectives)
sorted_pareto = sort_pareto_frontier(combined_pareto_frontier, labels)

x_min, x_max, y_min, y_max = add_frontier(axis[1], combined_pareto_frontier, "black", 'v', "Global P. Frontier", objectives)

for label, pareto in sorted_pareto.items():
    if len(pareto) > 0:
        add_scatter(axis[1], pareto, color_map[label], marker_map[label], label, objectives)

if objectives[0].is_better_higher():
    axis[1].invert_xaxis()

if objectives[1].is_better_higher():
    axis[1].invert_yaxis()

axis[1].set_xlabel(pretty_names[objectives[0].get_name()])
axis[1].set_ylabel(pretty_names[objectives[1].get_name()])

axis[1].legend(loc="lower left", ncol=1, fontsize=11)
axis[1].grid(True, which="major", color="lightgray")
axis[1].grid(True, which="minor", color="whitesmoke")

axis[1].set_title("(b)", loc="center")

middle_ticks = np.arange(0.2, 1.1, 0.1)
ticks = [x_min] + list(middle_ticks)
axis[1].set_xticklabels(axis[0].get_xticks(), rotation=-60)
axis[1].set_xticks(ticks)
axis[1].xaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.3f}" if x not in np.arange(0.2, 1.1, 0.1) else f"{x:.1f}")
)

steps = 7
step = (y_max - y_min) / steps
ticks = np.arange(y_min, y_max + step, step)
axis[1].set_yticks(ticks)
axis[1].yaxis.set_major_formatter(
    FuncFormatter(lambda x, _: f"{x:.2f}")
)


plt.tight_layout()
# plt.show()
plt.savefig("image.png", dpi=150)
# Out:
# /tmp/ipykernel_1/3219219765.py:32: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis[0].set_xticklabels(axis[0].get_xticks(), rotation=-60)
# /tmp/ipykernel_1/3219219765.py:76: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axis[1].set_xticklabels(axis[0].get_xticks(), rotation=-60)

# %%
objectives = [
    PredictionCoverageStrategy,
    MAEStrategy,
    TotalTimeStrategyMock,
    PrecisionAtKStrategy,
    RecallAtKStrategy,
    NDCGStrategy,
]

number_of_optimal = {label: [] for label in labels}

# for i in range(2, 5):
for i in range(2, len(objectives) + 1):

    current_objectives = objectives[:i]

    print(current_objectives)

    combined_pareto_frontier, _ = get_pareto_frontier(combined_solutions, current_objectives)
    sorted_pareto = sort_pareto_frontier(combined_pareto_frontier, labels)

    for label, pareto in sorted_pareto.items():
        number_of_optimal[label].append(len(pareto))
# Out:
# [<class 'evaluation.strategies.PredictionCoverageStrategy'>, <class 'evaluation.strategies.MAEStrategy'>]
# [<class 'evaluation.strategies.PredictionCoverageStrategy'>, <class 'evaluation.strategies.MAEStrategy'>, <class '__main__.TotalTimeStrategyMock'>]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 19
#      15 current_objectives = objectives[:i]
#      17 print(current_objectives)
# ---> 19 combined_pareto_frontier, _ = get_pareto_frontier(combined_solutions, current_objectives)
#      20 sorted_pareto = sort_pareto_frontier(combined_pareto_frontier, labels)
#      22 for label, pareto in sorted_pareto.items():
#
# Cell In[52], line 47, in get_pareto_frontier(solutions, objectives)
#      41 for solution_id, solution in enumerate(pareto_frontier):
#      43     pareto_frontier_without_solution = [
#      44         s for i, s in enumerate(pareto_frontier) if i != solution_id
#      45     ]
# ---> 47     strongly_dominated_solutions = get_all_strongly_dominated_solutions(
#      48         solution, pareto_frontier_without_solution, objectives
#      49     )
#      50     if strongly_dominated_solutions:
#      51         pareto_frontier_without_solution, removed = remove_indices(
#      52             pareto_frontier_without_solution, strongly_dominated_solutions
#      53         )
#
# Cell In[52], line 25, in get_all_strongly_dominated_solutions(solution, solutions, objectives)
#      24 def get_all_strongly_dominated_solutions(solution, solutions, objectives):
# ---> 25     return [id for id, s in enumerate(solutions) if dominates(solution[1], s[1], objectives)]
#
# Cell In[52], line 25, in <listcomp>(.0)
#      24 def get_all_strongly_dominated_solutions(solution, solutions, objectives):
# ---> 25     return [id for id, s in enumerate(solutions) if dominates(solution[1], s[1], objectives)]
#
# Cell In[52], line 13, in dominates(a, b, objectives)
#      10 for objective in objectives:
#      11     direction = 1 if objective.is_better_higher() else -1
# ---> 13     a_mean = np.mean(a[objective.get_name()])
#      14     b_mean = np.mean(b[objective.get_name()])
#      16     if direction * a_mean >= direction * b_mean:
#
# File /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:101, in _mean(a, axis, dtype, out, keepdims, where)
#      98     else:
#      99         return um.clip(a, min, max, out=out, **kwargs)
# --> 101 def _mean(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#     102     arr = asanyarray(a)
#     104     is_float16_result = False
#
# KeyboardInterrupt:

# %%
import json

# from evaluation.benchmark import FallbackEncoder

with open("number_of_optimal.results", "w") as file_object:
    json.dump(number_of_optimal, file_object, indent=4)

# %%
# figure_size = (12, 5)

# fig, axis = plt.subplots(1, 1, figsize=figure_size)
fig, axis = plt.subplots(1, 2, figsize=(12, 6))

axisb = axis[1]
axis = axis[0]


for label, number in number_of_optimal.items():
    axis.plot(
        range(2, len(objectives) + 1),
        number,
        label=label,
        color=color_map[label],
        linewidth=3,
        marker="v",
        markersize=10,
    )


axis.set_ylim([None, 180])
axis.set_xticks(range(2, 7))
axis.set_xlabel("Number of Objectives")
axis.set_ylabel("Number of Optimal Solutions")
# axis2.set_ylabel("Ratio of Optimal Solutions")

axis.legend(loc="upper left", ncol=2, fontsize=11)

# axis.xaxis.set_minor_locator(
#     ticker.AutoMinorLocator(2)
# )  # Draw 2 minor grid lines per major grid line on the x-axis
axis.yaxis.set_minor_locator(ticker.AutoMinorLocator(2))
axis.grid(True, which="major", color="lightgray")
axis.grid(True, which="minor", color="whitesmoke")
axis.set_title("(a)", loc="center")


total_number = []
for solutions in zip(*number_of_optimal.values()):
    total_number.append(sum(solutions) / len(combined_solutions))
axisb.plot(
    range(2, len(objectives) + 1),
    total_number,
    label=f"{label} (Total: {total_number})",
    color="black",
    linewidth=3,
    marker="v",
    markersize=10,
)

axisb.set_xticks(range(2, 7))
axisb.set_xlabel("Number of Objectives")
axisb.set_ylabel("|Optimal Solutions| / |Total Solutions|")

# axis.xaxis.set_minor_locator(
#     ticker.AutoMinorLocator(2)
# )  # Draw 2 minor grid lines per major grid line on the x-axis
axisb.yaxis.set_minor_locator(ticker.AutoMinorLocator(2))
axisb.grid(True, which="major", color="lightgray")
axisb.grid(True, which="minor", color="whitesmoke")
axisb.set_title("(b)", loc="center")


plt.savefig("image.png", dpi=150)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 11
#       7 axis = axis[0]
#      10 for label, number in number_of_optimal.items():
# ---> 11     axis.plot(
#      12         range(2, len(objectives) + 1),
#      13         number,
#      14         label=label,
#      15         color=color_map[label],
#      16         linewidth=3,
#      17         marker="v",
#      18         markersize=10,
#      19     )
#      22 axis.set_ylim([None, 180])
#      23 axis.set_xticks(range(2, 7))
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
# --> 486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#     488 if x.ndim > 2 or y.ndim > 2:
#     489     raise ValueError(f"x and y can be no greater than 2D, but have "
#     490                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (5,) and (1,)
